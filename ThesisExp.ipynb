# %% [markdown]
# <a href="https://colab.research.google.com/github/Orti-G/Thesis/blob/ML_Training/ThesisExp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('sample')
# Out:
# sample
